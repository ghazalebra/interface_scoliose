# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = range(1, 11)
y1 = np.ones(10)
y2 = np.empty((10,))
y2[:] = np.nan

fig, ax1 = plt.subplots()
ax1.plot(x, y1)
ax1.plot(x,y2)

plt.show()
